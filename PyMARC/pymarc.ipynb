# %% [markdown]
# # Instalar dependências

# %%
! pip install pymarc

# %%
from pymarc import MARCReader
with open('mrc/koha_ibram_20230703.mrc', 'rb') as fh:
    reader = MARCReader(fh)
    for record in reader:
        print(record.title)
# Out:
# Registro teste
# Registro teste
# Performing the past a study of israeli settlement museums
# Museu, educação e cultura: encontros de crianças e professores com a arte /
# A ordem dos livros na biblioteca:  uma abordagem preliminar ao Sistema de Localização Fixa.
# Acessibilidade e visibilidade de revistas científicas eletrônicas.
# Aisthesis:  estética, educação e comunidades.
# Arquivística:  temas contemporâneos: classificação, preservação digital, gestão do conhecimento.
# Arquivo:  teoria e prática.
# Arquivologia e ciência da informação.
# Arquivos permanentes:  tratamento documental.
# Arquivos modernos:  princípios e técnicas.
# As árvores de conhecimentos.
# As inteligências múltiplas e seus estímulos.
# Atores em rede:  olhares luso-brasileiros.
# Cabeçalhos para entidades coletivas.
# Cibercultura.
# A sociedade em rede.
# Entre olhares e leituras:  uma abordagem da Bienal do Mercosul.
# Educação inclusiva:  contextos sociais.
# Direito autoral no Brasil.
# ...
